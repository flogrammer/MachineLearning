# %%
import os
import numpy as np
from collections import Counter
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt

# %%
print("########################## EMAIL ANALYTICS #################################")
# Out:
# ########################## EMAIL ANALYTICS #################################

# %%
#Create dictionary for the specified train_dir
def make_Dictionary(train_dir):
    emails = [os.path.join(train_dir,f) for f in os.listdir(train_dir)]
    all_words = []      
    for mail in emails:  
        with open(mail) as m:
            for i,line in enumerate(m):  
                if i == 2:
                    words = line.split()
                    all_words += words #Add words to list
    #Count all words
    dictionary = Counter(all_words)
    list_to_remove = list(dictionary)
    for item in list_to_remove:
        #remove special characters and 1's
        if item.isalpha() == False: 
            del dictionary[item]
        elif len(item) == 1:
            del dictionary[item]
    dictionary = dictionary.most_common(700) 
    return dictionary

# %%
print("##################### GET DATA ##########################")
train_dir = 'C:/Users/Florian/Desktop/Programmierprojekt Python/Machine Learning 1/Machine Learning Implementations/MachineLearning/datasets/ling-spam/train-mails'
test_dir = 'C:/Users/Florian/Desktop/Programmierprojekt Python/Machine Learning 1/Machine Learning Implementations/MachineLearning/datasets/ling-spam/test-mails'
data_dictionary = make_Dictionary(train_dir)
test_dictionary = make_Dictionary(test_dir)
print(data_dictionary)
print("##########################################################")
print(test_dictionary)
# Out:
# ##################### GET DATA ##########################
# [('order', 1414), ('address', 1293), ('report', 1216), ('mail', 1127), ('send', 1079), ('language', 1072), ('email', 1051), ('program', 1001), ('our', 987), ('list', 935), ('one', 917), ('name', 878), ('receive', 826), ('money', 788), ('free', 762), ('work', 755), ('information', 677), ('business', 654), ('please', 652), ('university', 595), ('us', 564), ('day', 556), ('follow', 544), ('internet', 520), ('over', 511), ('http', 479), ('check', 472), ('call', 469), ('each', 466), ('include', 452), ('com', 448), ('linguistic', 442), ('number', 423), ('want', 420), ('letter', 419), ('need', 418), ('many', 412), ('here', 397), ('market', 395), ('start', 390), ('even', 386), ('fax', 383), ('form', 380), ('most', 377), ('first', 373), ('web', 366), ('service', 363), ('interest', 362), ('software', 352), ('remove', 349), ('read', 347), ('those', 345), ('week', 344), ('every', 332), ('credit', 329), ('ll', 326), ('site', 320), ('much', 318), ('english', 318), ('edu', 318), ('product', 317), ('bulk', 312), ('phone', 311), ('must', 299), ('two', 298), ('offer', 297), ('cost', 294), ('best', 291), ('www', 290), ('computer', 289), ('link', 283), ('state', 279), ('card', 278), ('de', 272), ('home', 268), ('available', 266), ('system', 264), ('message', 260), ('own', 260), ('after', 258), ('question', 257), ('opportunity', 257), ('place', 256), ('pay', 256), ('within', 254), ('million', 254), ('write', 253), ('hour', 253), ('world', 253), ('sell', 251), ('help', 248), ('copy', 248), ('show', 248), ('below', 247), ('same', 242), ('conference', 241), ('file', 238), ('through', 235), ('directory', 234), ('before', 232), ('where', 229), ('easy', 229), ('book', 226), ('try', 226), ('income', 226), ('thank', 225), ('tell', 222), ('today', 220), ('company', 219), ('member', 216), ('word', 215), ('example', 215), ('back', 214), ('different', 213), ('advertise', 213), ('month', 210), ('subject', 209), ('etc', 207), ('ask', 206), ('contact', 206), ('response', 204), ('cash', 204), ('little', 203), ('learn', 203), ('add', 202), ('cd', 200), ('linguist', 198), ('research', 198), ('per', 198), ('type', 197), ('down', 196), ('process', 196), ('anyone', 196), ('again', 196), ('right', 196), ('least', 195), ('is', 195), ('ve', 195), ('special', 194), ('price', 193), ('level', 192), ('provide', 192), ('save', 192), ('re', 190), ('off', 190), ('live', 190), ('require', 188), ('few', 186), ('change', 186), ('line', 186), ('sure', 186), ('financial', 186), ('box', 185), ('post', 185), ('search', 185), ('let', 184), ('ffa', 183), ('never', 181), ('paper', 179), ('thing', 177), ('four', 177), ('teach', 175), ('case', 175), ('life', 175), ('page', 174), ('participate', 173), ('text', 172), ('great', 172), ('really', 171), ('between', 170), ('both', 170), ('net', 170), ('buy', 169), ('success', 167), ('plan', 167), ('part', 166), ('move', 164), ('request', 164), ('instruction', 164), ('simply', 164), ('click', 164), ('package', 162), ('reply', 161), ('less', 160), ('point', 160), ('ever', 160), ('seem', 159), ('discourse', 158), ('several', 158), ('dollar', 158), ('theory', 157), ('method', 157), ('why', 157), ('win', 157), ('step', 157), ('student', 156), ('simple', 156), ('put', 155), ('thousand', 155), ('next', 154), ('important', 154), ('friend', 154), ('ship', 154), ('linguistics', 153), ('rate', 153), ('guarantee', 153), ('legal', 152), ('fact', 150), ('note', 150), ('course', 150), ('floodgate', 150), ('under', 148), ('account', 147), ('talk', 147), ('return', 146), ('since', 146), ('allow', 146), ('school', 145), ('position', 145), ('american', 145), ('keep', 145), ('until', 145), ('result', 144), ('analysis', 143), ('experience', 143), ('present', 143), ('ad', 143), ('study', 142), ('reference', 142), ('remember', 142), ('another', 141), ('better', 141), ('sale', 141), ('speaker', 139), ('city', 139), ('wish', 139), ('problem', 139), ('group', 139), ('believe', 139), ('person', 139), ('bank', 138), ('full', 136), ('vium', 136), ('leave', 136), ('once', 136 ...
# ##########################################################
# [('university', 582), ('language', 479), ('http', 395), ('information', 357), ('our', 341), ('address', 336), ('de', 323), ('com', 322), ('conference', 305), ('email', 272), ('one', 268), ('order', 248), ('please', 248), ('paper', 230), ('program', 229), ('www', 225), ('include', 224), ('web', 219), ('fax', 217), ('list', 216), ('send', 216), ('papers', 211), ('name', 211), ('workshop', 210), ('site', 209), ('linguistic', 203), ('mail', 199), ('call', 184), ('submission', 183), ('free', 181), ('work', 180), ('follow', 169), ('receive', 164), ('report', 159), ('system', 159), ('us', 158), ('research', 152), ('day', 151), ('edu', 150), ('usa', 149), ('over', 148), ('abstract', 147), ('registration', 147), ('first', 142), ('each', 137), ('internet', 137), ('uk', 137), ('win', 136), ('session', 132), ('interest', 130), ('offer', 130), ('word', 127), ('form', 125), ('product', 124), ('here', 122), ('copy', 119), ('want', 118), ('speech', 116), ('capitalfm', 114), ('provide', 113), ('number', 113), ('process', 110), ('international', 109), ('science', 106), ('click', 106), ('english', 105), ('world', 105), ('check', 105), ('week', 104), ('those', 104), ('below', 104), ('resource', 104), ('present', 103), ('available', 103), ('business', 103), ('need', 102), ('best', 102), ('remove', 102), ('between', 101), ('submit', 100), ('page', 99), ('many', 99), ('issue', 98), ('within', 96), ('state', 96), ('market', 95), ('analysis', 94), ('study', 94), ('part', 94), ('place', 94), ('money', 94), ('theory', 93), ('html', 93), ('special', 93), ('contact', 91), ('subject', 90), ('invite', 90), ('technology', 89), ('most', 89), ('area', 88), ('student', 88), ('book', 88), ('fee', 86), ('must', 86), ('two', 84), ('note', 83), ('where', 83), ('before', 83), ('evaluation', 83), ('account', 82), ('is', 82), ('review', 82), ('message', 81), ('company', 81), ('every', 81), ('ac', 79), ('much', 79), ('course', 78), ('text', 78), ('author', 77), ('service', 77), ('coffee', 77), ('structure', 76), ('question', 76), ('base', 75), ('publication', 75), ('june', 75), ('price', 74), ('title', 74), ('credit', 74), ('result', 73), ('institute', 73), ('discussion', 73), ('card', 73), ('learn', 73), ('committee', 72), ('start', 72), ('deadline', 72), ('million', 72), ('john', 71), ('type', 71), ('department', 71), ('own', 70), ('date', 70), ('volume', 69), ('topic', 69), ('level', 69), ('pay', 68), ('live', 68), ('case', 68), ('knowledge', 68), ('full', 68), ('phone', 68), ('different', 67), ('tel', 67), ('computer', 67), ('per', 67), ('method', 67), ('after', 66), ('participant', 65), ('lexical', 65), ('payment', 65), ('linguistics', 64), ('july', 64), ('help', 64), ('problem', 64), ('software', 64), ('advertisement', 64), ('speaker', 63), ('datum', 63), ('accept', 63), ('both', 62), ('event', 62), ('line', 62), ('today', 62), ('further', 61), ('la', 61), ('le', 61), ('european', 61), ('minute', 61), ('under', 61), ('change', 60), ('home', 60), ('detail', 60), ('great', 60), ('model', 59), ('grammar', 59), ('back', 59), ('search', 59), ('point', 59), ('read', 59), ('link', 59), ('through', 58), ('while', 58), ('electronic', 58), ('file', 58), ('end', 58), ('presentation', 58), ('show', 57), ('right', 57), ('approach', 57), ('access', 57), ('next', 57), ('break', 57), ('et', 56), ('japan', 56), ('publish', 56), ('cognitive', 56), ('even', 56), ('september', 55), ('request', 55), ('movement', 55), ('pm', 55), ('experience', 54), ('london', 54), ('cd', 54), ('inc', 53), ('focus', 53), ('communication', 53), ('ll', 53), ('general', 53), ('field', 53), ('second', 53), ('france', 53), ('visit', 53), ('march', 53), ('verb', 52), ('stanford', 52), ('thank', 52), ('limit', 52), ('format', 52), ('latest', 52), ('write', 51), ('development', 51), ('four', 51), ('journal', 51), ('hold', 51), ('semantic', 51), ('member', 50), ('three', 50), ('etc', 50), ('add', 50), ('sign', 50), ('acquisition', 50), ('ticket', 50), ('advertise', 50), ('album', 50), ('digital', 49), ('put',  ...
